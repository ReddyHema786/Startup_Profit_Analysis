# %% [markdown]
# ***Startup Profit Analysis***
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("/content/startup_data.csv")

# %%
df.head()
# Out:
#     RD_Spend  Administration  Marketing_Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of      RD_Spend  Administration  Marketing_Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.describe()
# Out:
#             RD_Spend  Administration  Marketing_Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df.columns
# Out:
# Index(['RD_Spend', 'Administration', 'Marketing_Spend', 'State', 'Profit'], dtype='object')

# %%
df.isnull().sum()
# Out:
# RD_Spend           0
# Administration     0
# Marketing_Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['State'].value_counts()
# Out:
# State
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5)),
sns.histplot(df['Profit'], kde=True)
plt.title("Profit Distribution"),
plt.xlabel('Profit'),
plt.ylabel('Frequency'),
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="RD_Spend",y="Profit")
plt.title("R&D Spending vs Profit")
plt.xlabel("R&D Spending")
plt.ylabel("Profit")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x="Marketing_Spend",y="Profit")
plt.title("Marketing Spend vs Profit")
plt.xlabel('Marketing Spending')
plt.ylabel('Profit')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="Administration", y="Profit")
plt.title("Administration Spend vs Profit")
plt.xlabel('Administration Spending')
plt.ylabel('Profit')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x="State",y="Profit")
plt.title('Profit by State')
plt.xticks(rotation=45)
plt.show()

# %%
correlation = df[[
    "RD_Spend",
    "Administration",
    "Marketing_Spend",
    "Profit"
]].corr()
print(correlation)
# Out:
#                  RD_Spend  Administration  Marketing_Spend    Profit
# RD_Spend         1.000000        0.241955         0.724248  0.972900
# Administration   0.241955        1.000000        -0.032154  0.200717
# Marketing_Spend  0.724248       -0.032154         1.000000  0.747766
# Profit           0.972900        0.200717         0.747766  1.000000

# %%
plt.figure(figsize=(8,5))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
x=df.drop('Profit', axis=1)
y=df['Profit']

# %%
x=pd.get_dummies(x, columns=['State'],drop_first=True)

# %%
x.head()
# Out:
#     RD_Spend  Administration  Marketing_Spend  State_Florida  State_New York
# 0  165349.20       136897.80        471784.10          False            True
# 1  162597.70       151377.59        443898.53          False           False
# 2  153441.51       101145.55        407934.54           True           False
# 3  144372.41       118671.85        383199.62          False            True
# 4  142107.34        91391.77        366168.42           True           False

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
comparison= pd.DataFrame({
    "Actual Profit": y_test.values,
    "Predicted Profit": y_pred
})
comparison
# Out:
#    Actual Profit  Predicted Profit
# 0      134307.35     126362.879083
# 1       81005.76      84608.453836
# 2       99937.59      99677.494251
# 3       64926.08      46357.460686
# 4      125370.37     128750.482885
# 5       35673.41      50912.417419
# 6      105733.54     109741.350327
# 7      107404.34     100643.242816
# 8       97427.84      97599.275746
# 9      122776.86     113097.425244

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mean_squared_error(y_test,y_pred))

print("R^2 Score:", r2)
print("MAE:", mae)
print("RMSE:",rmse)
# Out:
# R^2 Score: 0.8987266414328637
# MAE: 6961.477813252376
# RMSE: 9055.957323458464

# %%
coefficients=pd.DataFrame({
    "Feature":x.columns,
    "Coefficients":model.coef_
})

coefficients
# Out:
#            Feature  Coefficients
# 0         RD_Spend      0.805630
# 1   Administration     -0.068788
# 2  Marketing_Spend      0.029855
# 3    State_Florida    938.793006
# 4   State_New York      6.987760

# %%
print("Intercept:",model.intercept_)
# Out:
# Intercept: 54028.03959364581

# %%
plt.figure(figsize=(8,5))
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Profit")
plt.ylabel("Predicted Profit")
plt.title("Actual Vs  Predicted Profit")
plt.show()

# %% [markdown]
# **Business Insights:**
#
#  R&D Spending has the strongest positive relationship with Profit (correlation = 0.973), followed by Marketing Spending (0.748).
# Administration Spending has a comparatively weak relationship with Profit (0.201).
# [link text](https://)New York has the highest total profit, while Florida has the highest average profit per startup.
# The analysis suggests that effective R&D and Mark
# eting investments are important factors associated with higher startup profitability.
# A Linear Regression model was developed to predict Profit and support data-driven business decisions.

# %% [markdown]
# **Conclusion:**
#
# This project analyzed the relationship between startup investments and profitability using data analysis and regression techniques. The analysis showed that R&D spending has the strongest positive relationship with Profit, followed by Marketing Spending, while Administration Spending has a relatively weaker relationship with profitability. The comparison across states also showed differences in startup profitability, with New York having the highest total profit and Florida having the highest average profit per startup.
#
# A Linear Regression model was developed to predict startup Profit using R&D Spending, Administration Spending, Marketing Spending, and State. The model evaluation metrics such as R², MAE, and RMSE can be used to assess its prediction performance. Overall, the project demonstrates how data analysis and machine learning can help identify important factors affecting startup profitability and support data-driven investment and business decisions.
